# %% [markdown]
# Logistic Regression

# %%
import pandas as pd
train = pd.read_csv('Train_100.csv')
train
# Out:
# C:\Users\moise\AppData\Local\Temp\ipykernel_18872\1732597533.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#              Rojo     Verde      Azul       hue       sat    values   fourier  \
# 0        0.720784  0.685556  0.612005  0.022351  0.101119  0.692760  0.036092
# 1        0.727376  0.688613  0.617152  0.019977  0.103178  0.700013  0.036095
# 2        0.728381  0.690723  0.618759  0.021525  0.102467  0.701119  0.036091
# 3        0.733201  0.692503  0.622108  0.019535  0.104470  0.706423  0.036081
# 4        0.735993  0.693652  0.626288  0.015800  0.102859  0.709495  0.036099
# ...

# %%
val = pd.read_csv('Val_100.csv')
val
# Out:
#             Rojo     Verde      Azul       hue       sat    values   fourier  \
# 0       0.672948  0.642778  0.667608  0.017481  0.137872  0.672948  0.015705
# 1       0.680886  0.645366  0.665830  0.021071  0.153711  0.680886  0.015693
# 2       0.678263  0.646910  0.667950  0.021050  0.145725  0.678263  0.015697
# 3       0.680296  0.649629  0.673351  0.018390  0.139194  0.680296  0.015693
# 4       0.688970  0.650173  0.678566  0.012721  0.143548  0.688970  0.015681
# ...          ...       ...       ...       ...       ...       ...       ...
# 119995  0.420828  0.435904  0.432179  0.061412  0.167053  0.420828  0.015685
# 119996  0.415400  0.431453  0.422729  0.065814  0.177516  0.415400  0.015706
# 119997  0.414221  0.427970  0.422473  0.062366  0.175821  0.414221  0.015675
# 119998  0.404696  0.416934  0.411492  0.061870  0.181911  0.404696  0.015709
# 119999  0.404924  0.417164  0.409301  0.063693  0.187242  0.404924  0.015676
#
#             gray   entropy  etiquetas
# ...

# %%
test = pd.read_csv('Test_100.csv')
test
# Out:
#             Rojo     Verde      Azul       hue       sat    values   fourier  \
# 0       0.637850  0.616612  0.464981  0.018077  0.166010  0.548157  0.016372
# 1       0.637474  0.619819  0.467805  0.020277  0.160265  0.547688  0.016368
# 2       0.637547  0.621788  0.467800  0.023102  0.160439  0.547779  0.016372
# 3       0.637613  0.624695  0.475603  0.020545  0.147073  0.547862  0.016369
# 4       0.645292  0.626000  0.477048  0.019833  0.162014  0.557443  0.016360
# ...          ...       ...       ...       ...       ...       ...       ...
# 119995  0.436658  0.441263  0.159192  0.060781  0.253798  0.297137  0.016365
# 119996  0.432073  0.434750  0.151939  0.058559  0.256797  0.291417  0.016349
# 119997  0.427324  0.431741  0.148753  0.058638  0.250876  0.285492  0.016382
# 119998  0.416125  0.423299  0.134599  0.060976  0.250747  0.271519  0.016356
# 119999  0.414326  0.426251  0.141119  0.062079  0.232076  0.269274  0.016377
#
#             gray   entropy  etiquetas
# ...

# %%
X_train = train[["Rojo", "Verde", "Azul", "hue", "sat", "values", "fourier", "gray", "entropy"]]
y_train = train["etiquetas"]

# %%
X_val = val[["Rojo", "Verde", "Azul", "hue", "sat", "values", "fourier", "gray", "entropy"]]
y_val = val["etiquetas"]

# %%
X_test = test[["Rojo", "Verde", "Azul", "hue", "sat", "values", "fourier", "gray", "entropy"]]
y_test = test["etiquetas"]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1510000, 9)
# (1510000,)

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (1510000, 9)
# (1510000,)
# (120000, 9)
# (120000,)
# (120000, 9)
# (120000,)

# %%
from sklearn.linear_model import LogisticRegression

param_grid = {
    'C': [0.1, 1, 10],
    'penalty': ['l2'],
    'multi_class': ['multinomial', 'ovr'],
    'solver': ['newton-cg', 'sag' ],
    'max_iter': [100, 500, 1000]
}

# %%
lr_model = LogisticRegression()

# %%
cv = StratifiedKFold(n_splits=5, shuffle=False)

# %%
grid_search = GridSearchCV(estimator=lr_model, param_grid=param_grid, scoring='accuracy', refit=True, cv=cv, n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10], 'max_iter': [100, 500, 1000],
#                          'multi_class': ['multinomial', 'ovr'],
#                          'penalty': ['l2'], 'solver': ['newton-cg', 'sag']},
#              scoring='accuracy')

# %%
best_params = grid_search.best_params_
best_params
# Out:
# {'C': 10,
#  'max_iter': 100,
#  'multi_class': 'multinomial',
#  'penalty': 'l2',
#  'solver': 'sag'}

# %%
y_pred_train = grid_search.predict(X_train)

# %%
train_lr_accuracy = accuracy_score(y_train, y_pred_train)

print("Logistic Regression Accuracy train:", train_lr_accuracy)
# Out:
# Logistic Regression Accuracy train: 0.4618456953642384

# %%
from sklearn.metrics import classification_report

train_report = classification_report(y_train, y_pred_train)
print('train report: ', train_report)
# Out:
# train report:                precision    recall  f1-score   support
#
#          0.0       0.61      0.33      0.43    340000
#          1.0       0.43      0.12      0.19    530000
#          2.0       0.44      0.81      0.57    640000
#
#     accuracy                           0.46   1510000
#    macro avg       0.49      0.42      0.40   1510000
# weighted avg       0.48      0.46      0.41   1510000

# %%
y_pred_val = grid_search.predict(X_val)

# %%
val_lr_accuracy = accuracy_score(y_val, y_pred_val)

print("Logistic Regression Accuracy_val:", val_lr_accuracy)
# Out:
# Logistic Regression Accuracy_val: 0.35834166666666667

# %%
val_report = classification_report(y_val, y_pred_val)
print('val report:', val_report)
# Out:
# val report:               precision    recall  f1-score   support
#
#          0.0       0.33      0.78      0.47     40000
#          1.0       0.27      0.00      0.00     40000
#          2.0       0.44      0.30      0.36     40000
#
#     accuracy                           0.36    120000
#    macro avg       0.35      0.36      0.27    120000
# weighted avg       0.35      0.36      0.27    120000

# %%
y_pred_test = grid_search.predict(X_test)

# %%
test_lr_accuracy = accuracy_score(y_val, y_pred_test)

print("Logistic Regression Accuracy_test:", test_lr_accuracy)
# Out:
# Logistic Regression Accuracy_test: 0.279625

# %%
test_report = classification_report(y_test, y_pred_test)
print('test report:', val_report)
# Out:
# test report:               precision    recall  f1-score   support
#
#          0.0       0.33      0.78      0.47     40000
#          1.0       0.27      0.00      0.00     40000
#          2.0       0.44      0.30      0.36     40000
#
#     accuracy                           0.36    120000
#    macro avg       0.35      0.36      0.27    120000
# weighted avg       0.35      0.36      0.27    120000
